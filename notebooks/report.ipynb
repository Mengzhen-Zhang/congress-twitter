# %%
import warnings
warnings.filterwarnings('ignore')

import sys
from pathlib import Path
PROJECT_ROOT = Path().resolve().parent
DATA_ROOT = f"{PROJECT_ROOT}/data"

# %load_ext autoreload
# %autoreload 2
from src.features import build_features
from src.visualization import visualize
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Build and save features

# %%
# features = build_features.build_feautures()
# features.initialize()

# %% [markdown]
# # Make Figures

# %%
visualize.make_word_cloud_grid()

# %%
visualize.plot_theme_year()

# %%
visualize.make_theme_grid()

# %%
import matplotlib.pyplot as plt
df = visualize.tweets
df['sentiment'][df['year'] == 2008 ].hist()
plt.xlim((-1, 1))
# Out:
# (-1.0, 1.0)
