# %%
import warnings
warnings.filterwarnings('ignore')
import sys
from pathlib import Path
PROJECT_ROOT = Path().resolve().parent
sys.path.insert(1, str(PROJECT_ROOT))

# %load_ext autoreload
# %autoreload 2

# %%
# from src.features import build_features
# features = build_features.build_feautures()
# features.initialize()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# loading raw data from /home/mz343/projects/congress-twitter/data/raw
# raw tweets loaded
# raw users loaded
# tweets created
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1243370 entries, 0 to 1243369
# Data columns (total 7 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   created_at           1243370 non-null  datetime64[ns]
#  1   id                   1243370 non-null  int64
#  2   in_reply_to_user_id  65411 non-null    float64
#  3   text                 1243370 non-null  object
#  4   user_id              1243370 non-null  int64
#  5   year                 1243370 non-null  int32
#  6   sentiment            1243370 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(2), object(1)
# memory usage: 61.7+ MB
# None
# users created
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           548 non-null    int64
#  1   name         548 non-null    object
#  2   screen_name  548 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 13.0+ KB
# None
# mentions created
# <class 'pandas.core.frame.DataFrame'>
# Index: 768245 entries, 2 to 1243368
# Data columns (total 2 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   tweet_id      768245 non-null  int64
#  1   mentioned_id  768245 non-null  Int64
# dtypes: Int64(1), int64(1)
# memory usage: 18.3 MB
# None
# mentioned_members created
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529 entries, 0 to 528
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   screen_name  529 non-null    object
#  1   count        529 non-null    Int64
# dtypes: Int64(1), object(1)
# memory usage: 8.9+ KB
# None
# mentioned_members_outliers created
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   screen_name  20 non-null     object
#  1   count        20 non-null     Int64
# dtypes: Int64(1), object(1)
# memory usage: 500.0+ bytes
# None
# topics created
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1243370 entries, 0 to 1243369
# Data columns (total 10 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   id            1243370 non-null  int64
#  1   created_at    1243370 non-null  datetime64[ns]
#  2   text          1243370 non-null  object
#  3   year          1243370 non-null  int32
#  4   theme_health  1243370 non-null  Int64
#  5   theme_work    1243370 non-null  Int64
#  6   theme_house   1243370 non-null  Int64
#  7   theme_tax     1243370 non-null  Int64
#  8   theme_auto    1243370 non-null  Int64
#  9   theme_trade   1243370 non-null  Int64
# dtypes: Int64(6), datetime64[ns](1), int32(1), int64(1), object(1)
# memory usage: 97.2+ MB
# None
# theme_counts created
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   theme   6 non-null      object
#  1   count   6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 228.0+ bytes
# None
# topics_year created
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          10 non-null     int32
#  1   id            10 non-null     int64
#  2   theme_health  10 non-null     Int64
#  3   theme_work    10 non-null     Int64
#  4   theme_house   10 non-null     Int64
#  5   theme_tax     10 non-null     Int64
#  6   theme_auto    10 non-null     Int64
#  7   theme_trade   10 non-null     Int64
# dtypes: Int64(6), int32(1), int64(1)
# memory usage: 792.0 bytes
# None
# theme_year_count created
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    60 non-null     int32
#  1   count   60 non-null     Int64
#  2   theme   60 non-null     object
# dtypes: Int64(1), int32(1), object(1)
# memory usage: 1.7+ KB
# None
# popular_member_tweets created
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456 entries, 0 to 455
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   screen_name  456 non-null    object
#  1   year         456 non-null    int32
#  2   theme        456 non-null    object
#  3   score        456 non-null    float64
# dtypes: float64(1), int32(1), object(2)
# memory usage: 12.6+ KB
# None

# %% [markdown]
# # Make Figures

# %%
from src.visualization import visualize
import pandas as pd

# %%
visualize.make_word_cloud_grid()

# %%
visualize.plot_theme_year()

# %%
visualize.make_theme_grid()

# %%
import matplotlib.pyplot as plt
df = visualize.tweets
df['sentiment'][df['year'] == 2008 ].hist()
plt.xlim((-1, 1))
# Out:
# (-1.0, 1.0)
